# %%
import pandas as pd
from rdkit import Chem

# Função para canonizar SMILES
def canonize_smiles(smiles):
    try:
        mol = Chem.MolFromSmiles(smiles)
        if mol:
            return Chem.MolToSmiles(mol, canonical=True)
        else:
            return None
    except:
        return None

# Função para remover SMILES inválidos
def remove_invalid_smiles(df, smiles_col):
    invalid_smiles = df[df[smiles_col].apply(lambda x: canonize_smiles(x) is None)]
    invalid_smiles['Reason'] = 'Invalid SMILES'
    df = df[df[smiles_col].apply(lambda x: canonize_smiles(x) is not None)]
    return df, invalid_smiles

# Função para remover duplicatas discordantes
def remove_discordant_duplicates(df, smiles_col, activity_col):
    # Canonizar os SMILES
    df['canonical_smiles'] = df[smiles_col].apply(canonize_smiles)
    
    # Encontrar duplicatas discordantes
    duplicates = df.duplicated(subset=['canonical_smiles', activity_col], keep=False)
    discordant = df[duplicates].groupby('canonical_smiles')[activity_col].nunique() > 1
    discordant_smiles = discordant[discordant].index
    
    # Registrar duplicatas discordantes
    discordant_duplicates = df[df['canonical_smiles'].isin(discordant_smiles)]
    discordant_duplicates['Reason'] = 'Discordant Duplicate'
    
    # Registrar duplicatas concordantes
    concordant_duplicates = df[duplicates & ~df['canonical_smiles'].isin(discordant_smiles)]
    concordant_duplicates['Reason'] = 'Concordant Duplicate'
    
    # Remover duplicatas discordantes e concordantes
    df = df[~df['canonical_smiles'].isin(discordant_smiles)]
    df = df.drop_duplicates(subset=['canonical_smiles', activity_col], keep='first')
    
    # Concatenar todas as remoções
    removed_smiles = pd.concat([discordant_duplicates, concordant_duplicates])
    
    # Remover a coluna de SMILES canonizados
    df = df.drop(columns=['canonical_smiles'])
    
    return df, removed_smiles

# Função para criar o log
def create_log(removed_df, log_file='log.txt'):
    invalid_count = len(removed_df[removed_df['Reason'] == 'Invalid SMILES'])
    discordant_count = len(removed_df[removed_df['Reason'] == 'Discordant Duplicate'])
    concordant_count = len(removed_df[removed_df['Reason'] == 'Concordant Duplicate'])
    
    with open(log_file, 'w') as f:
        f.write(f"Invalid SMILES removed: {invalid_count}\n")
        f.write(f"Discordant duplicates removed: {discordant_count}\n")
        f.write(f"Concordant duplicates removed: {concordant_count}\n")

# Função principal para executar o processo completo
def process_smiles(df, smiles_col, activity_col, log_file='log.txt'):
    # Remover SMILES inválidos
    df, invalid_smiles = remove_invalid_smiles(df, smiles_col)
    
    # Remover duplicatas discordantes e concordantes
    df, removed_smiles = remove_discordant_duplicates(df, smiles_col, activity_col)
    
    # Concatenar todas as remoções
    removed_smiles = pd.concat([invalid_smiles, removed_smiles])
    
    # Criar o log
    create_log(removed_smiles, log_file)
    
    return df, removed_smiles

# %%
df = pd.read_excel(r"C:\Users\franc\OneDrive\Documentos\LabMol\IC-Skin\DADOS\Binary\RAW_Skin_data_LLNA_Binary.xlsx")
df
# Out:
#           CAS No                      Canonical SMILES  LLNA_EC3  binary  \
# 0     18479-49-7                    CC(C)CCCC(C)(O)C=C       NaN       0
# 1        93-84-5         [O-][N+](=O)c1ccc2NC(=O)Nc2c1       NaN       0
# 2     38725-13-2  CC(C)CCCCCCN(CCCCCCC(C)C)CCCCCCC(C)C       NaN       1
# 3     49701-24-8        CN[S](=O)(=O)c1cc(OC)c(N)cc1OC       NaN       0
# 4      3874-54-2                 Fc1ccc(cc1)C(=O)CCCCl       NaN       1
# ...          ...                                   ...       ...     ...
# 3314    122-78-1                          O=CCc1ccccc1       4.7       0
# 3315    122-78-1                          O=CCc1ccccc1       3.0       1
# 3316    122-78-1                          O=CCc1ccccc1       8.8       0
# 3317  17369-59-4               CC/C=C/1OC(=O)c2ccccc12       3.7       0
# 3318  17369-59-4               CC/C=C/1OC(=O)c2ccccc12       3.1       0
#
#      Source
# 0      ECHA
# 1      ECHA
# 2      ECHA
# 3      ECHA
# 4      ECHA
# ...     ...
# 3314  CosEU
# 3315  CosEU
# 3316  CosEU
# 3317  CosEU
# 3318  CosEU
#
# [3319 rows x 5 columns]

# %%
# Executar o processo completo
df_cleaned, removed_smiles = process_smiles(df, smiles_col='Canonical SMILES', activity_col='binary')

# Salvar os resultados
df_cleaned.to_csv('cleaned_smiles.csv', index=False)
removed_smiles.to_csv('removed_smiles.csv', index=False)

print("Process completed. Check 'log.txt' for details.")
print(df_cleaned)
print(removed_smiles)
# Out:
# [14:50:07] SMILES Parse Error: syntax error while parsing: O|[Zn]|O
# [14:50:07] SMILES Parse Error: Failed parsing SMILES 'O|[Zn]|O' for input: 'O|[Zn]|O'
# [14:50:07] SMILES Parse Error: syntax error while parsing: O|[Zn]|O
# [14:50:07] SMILES Parse Error: Failed parsing SMILES 'O|[Zn]|O' for input: 'O|[Zn]|O'
# [14:50:07] SMILES Parse Error: syntax error while parsing: O|[Co](|O)|O
# [14:50:07] SMILES Parse Error: Failed parsing SMILES 'O|[Co](|O)|O' for input: 'O|[Co](|O)|O'
# [14:50:07] SMILES Parse Error: syntax error while parsing: [Na+].[Na+].[Cu]|1|OC(=O)CN(CCN(CC(O|1)=O)CC([O-])=O)CC([O-])=O
# [14:50:07] SMILES Parse Error: Failed parsing SMILES '[Na+].[Na+].[Cu]|1|OC(=O)CN(CCN(CC(O|1)=O)CC([O-])=O)CC([O-])=O' for input: '[Na+].[Na+].[Cu]|1|OC(=O)CN(CCN(CC(O|1)=O)CC([O-])=O)CC([O-])=O'
# [14:50:07] SMILES Parse Error: syntax error while parsing: N.N.O|[Fe]|1|OC(=O)CN(CCN(CC(O)=O)CC(O)=O)CC(O|1)=O
# [14:50:07] SMILES Parse Error: Failed parsing SMILES 'N.N.O|[Fe]|1|OC(=O)CN(CCN(CC(O)=O)CC(O)=O)CC(O|1)=O' for input: 'N.N.O|[Fe]|1|OC(=O)CN(CCN(CC(O)=O)CC(O)=O)CC(O|1)=O'
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] SMILES Parse Error: syntax error while parsing: C[Sn](|[S]CC(=O)OCC(CC)CCCC)(|[S]CC(=O)OCC(CC)CCCC)|[S]CC(=O)OCC(CC)CCCC
# [14:50:07] SMILES Parse Error: Failed parsing SMILES 'C[Sn](|[S]CC(=O)OCC(CC)CCCC)(|[S]CC(=O)OCC(CC)CCCC)|[S]CC(=O)OCC(CC)CCCC' for input: 'C[Sn](|[S]CC(=O)OCC(CC)CCCC)(|[S]CC(=O)OCC(CC)CCCC)|[S]CC(=O)OCC(CC)CCCC'
# [14:50:07] SMILES Parse Error: syntax error while parsing: C[Sn](|[S]CC(=O)OCC(CC)CCCC)(|[S]CC(=O)OCC(CC)CCCC)|[S]CC(=O)OCC(CC)CCCC
# [14:50:07] SMILES Parse Error: Failed parsing SMILES 'C[Sn](|[S]CC(=O)OCC(CC)CCCC)(|[S]CC(=O)OCC(CC)CCCC)|[S]CC(=O)OCC(CC)CCCC' for input: 'C[Sn](|[S]CC(=O)OCC(CC)CCCC)(|[S]CC(=O)OCC(CC)CCCC)|[S]CC(=O)OCC(CC)CCCC'
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] SMILES Parse Error: syntax error while parsing: [Cl]|[Sn](CCCC)(CCCC)CCCC
# [14:50:07] SMILES Parse Error: Failed parsing SMILES '[Cl]|[Sn](CCCC)(CCCC)CCCC' for input: '[Cl]|[Sn](CCCC)(CCCC)CCCC'
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] SMILES Parse Error: syntax error while parsing: [Cl]|[Pt--](|[Cl])(|[Cl])|[Cl].[K+].[K+]
# [14:50:07] SMILES Parse Error: Failed parsing SMILES '[Cl]|[Pt--](|[Cl])(|[Cl])|[Cl].[K+].[K+]' for input: '[Cl]|[Pt--](|[Cl])(|[Cl])|[Cl].[K+].[K+]'
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] SMILES Parse Error: syntax error while parsing: [Zn++](|S=C([S-])N(CC)c1ccccc1)|S=C([S-])N(CC)c2ccccc2
# [14:50:07] SMILES Parse Error: Failed parsing SMILES '[Zn++](|S=C([S-])N(CC)c1ccccc1)|S=C([S-])N(CC)c2ccccc2' for input: '[Zn++](|S=C([S-])N(CC)c1ccccc1)|S=C([S-])N(CC)c2ccccc2'
# [14:50:07] SMILES Parse Error: syntax error while parsing: O|[Pd]|O
# [14:50:07] SMILES Parse Error: Failed parsing SMILES 'O|[Pd]|O' for input: 'O|[Pd]|O'
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] SMILES Parse Error: syntax error while parsing: CCCCCCCC[Sn]|1(|[O]C(=O)CC[S]|1)CCCCCCCC
# [14:50:07] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCC[Sn]|1(|[O]C(=O)CC[S]|1)CCCCCCCC' for input: 'CCCCCCCC[Sn]|1(|[O]C(=O)CC[S]|1)CCCCCCCC'
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] SMILES Parse Error: syntax error while parsing: CCCCCCCC[Sn](|[O]C(=O)C(CC)CCCC)(|[O]C(=O)C(CC)CCCC)CCCCCCCC
# [14:50:07] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCC[Sn](|[O]C(=O)C(CC)CCCC)(|[O]C(=O)C(CC)CCCC)CCCCCCCC' for input: 'CCCCCCCC[Sn](|[O]C(=O)C(CC)CCCC)(|[O]C(=O)C(CC)CCCC)CCCCCCCC'
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] Explicit valence for atom # 0 O, 3, is greater than permitted
# [14:50:07] SMILES Parse Error: syntax error while parsing: [NH4+].[NH4+].[Cl]|[Pd--](|[Cl])(|[Cl])(|[Cl])(|[Cl])|[Cl]
# [14:50:07] SMILES Parse Error: Failed parsing SMILES '[NH4+].[NH4+].[Cl]|[Pd--](|[Cl])(|[Cl])(|[Cl])(|[Cl])|[Cl]' for input: '[NH4+].[NH4+].[Cl]|[Pd--](|[Cl])(|[Cl])(|[Cl])(|[Cl])|[Cl]'
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] SMILES Parse Error: syntax error while parsing: [Cl]|[Pd--](|[Cl])(|[Cl])(|[Cl])(|[Cl])|[Cl].[K+].[K+]
# [14:50:07] SMILES Parse Error: Failed parsing SMILES '[Cl]|[Pd--](|[Cl])(|[Cl])(|[Cl])(|[Cl])|[Cl].[K+].[K+]' for input: '[Cl]|[Pd--](|[Cl])(|[Cl])(|[Cl])(|[Cl])|[Cl].[K+].[K+]'
# [14:50:07] SMILES Parse Error: syntax error while parsing: CCCCCCCC[Sn](|[O]C(=O)\C=C\C(=O)OCC)(|[O]C(=O)\C=C\C(=O)OCC)CCCCCCCC
# [14:50:07] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCC[Sn](|[O]C(=O)\C=C\C(=O)OCC)(|[O]C(=O)\C=C\C(=O)OCC)CCCCCCCC' for input: 'CCCCCCCC[Sn](|[O]C(=O)\C=C\C(=O)OCC)(|[O]C(=O)\C=C\C(=O)OCC)CCCCCCCC'
# [14:50:07] SMILES Parse Error: syntax error while parsing: [Cl]|[Pt--](|[Cl])(|[Cl])(|[Cl])(|[Cl])|[Cl].[H+].[H+]
# [14:50:07] SMILES Parse Error: Failed parsing SMILES '[Cl]|[Pt--](|[Cl])(|[Cl])(|[Cl])(|[Cl])|[Cl].[H+].[H+]' for input: '[Cl]|[Pt--](|[Cl])(|[Cl])(|[Cl])(|[Cl])|[Cl].[H+].[H+]'
# [14:50:07] SMILES Parse Error: syntax error while parsing: [Cl]|[Pt--](|[Cl])(|[Cl])(|[Cl])(|[Cl])|[Cl].[K+].[K+]
# [14:50:07] SMILES Parse Error: Failed parsing SMILES '[Cl]|[Pt--](|[Cl])(|[Cl])(|[Cl])(|[Cl])|[Cl].[K+].[K+]' for input: '[Cl]|[Pt--](|[Cl])(|[Cl])(|[Cl])(|[Cl])|[Cl].[K+].[K+]'
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] SMILES Parse Error: syntax error while parsing: [Cl]|[Sn](|[Cl])(|[Cl])|[Cl]
# [14:50:07] SMILES Parse Error: Failed parsing SMILES '[Cl]|[Sn](|[Cl])(|[Cl])|[Cl]' for input: '[Cl]|[Sn](|[Cl])(|[Cl])|[Cl]'
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# C:\Users\franc\AppData\Local\Temp\ipykernel_26892\1027166548.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   invalid_smiles['Reason'] = 'Invalid SMILES'
# [14:50:07] SMILES Parse Error: syntax error while parsing: O|[Zn]|O
# [14:50:07] SMILES Parse Error: Failed parsing SMILES 'O|[Zn]|O' for input: 'O|[Zn]|O'
# [14:50:07] SMILES Parse Error: syntax error while parsing: O|[Zn]|O
# [14:50:07] SMILES Parse Error: Failed parsing SMILES 'O|[Zn]|O' for input: 'O|[Zn]|O'
# [14:50:07] SMILES Parse Error: syntax error while parsing: O|[Co](|O)|O
# [14:50:07] SMILES Parse Error: Failed parsing SMILES 'O|[Co](|O)|O' for input: 'O|[Co](|O)|O'
# [14:50:07] SMILES Parse Error: syntax error while parsing: [Na+].[Na+].[Cu]|1|OC(=O)CN(CCN(CC(O|1)=O)CC([O-])=O)CC([O-])=O
# [14:50:07] SMILES Parse Error: Failed parsing SMILES '[Na+].[Na+].[Cu]|1|OC(=O)CN(CCN(CC(O|1)=O)CC([O-])=O)CC([O-])=O' for input: '[Na+].[Na+].[Cu]|1|OC(=O)CN(CCN(CC(O|1)=O)CC([O-])=O)CC([O-])=O'
# [14:50:07] SMILES Parse Error: syntax error while parsing: N.N.O|[Fe]|1|OC(=O)CN(CCN(CC(O)=O)CC(O)=O)CC(O|1)=O
# [14:50:07] SMILES Parse Error: Failed parsing SMILES 'N.N.O|[Fe]|1|OC(=O)CN(CCN(CC(O)=O)CC(O)=O)CC(O|1)=O' for input: 'N.N.O|[Fe]|1|OC(=O)CN(CCN(CC(O)=O)CC(O)=O)CC(O|1)=O'
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] SMILES Parse Error: syntax error while parsing: C[Sn](|[S]CC(=O)OCC(CC)CCCC)(|[S]CC(=O)OCC(CC)CCCC)|[S]CC(=O)OCC(CC)CCCC
# [14:50:07] SMILES Parse Error: Failed parsing SMILES 'C[Sn](|[S]CC(=O)OCC(CC)CCCC)(|[S]CC(=O)OCC(CC)CCCC)|[S]CC(=O)OCC(CC)CCCC' for input: 'C[Sn](|[S]CC(=O)OCC(CC)CCCC)(|[S]CC(=O)OCC(CC)CCCC)|[S]CC(=O)OCC(CC)CCCC'
# [14:50:07] SMILES Parse Error: syntax error while parsing: C[Sn](|[S]CC(=O)OCC(CC)CCCC)(|[S]CC(=O)OCC(CC)CCCC)|[S]CC(=O)OCC(CC)CCCC
# [14:50:07] SMILES Parse Error: Failed parsing SMILES 'C[Sn](|[S]CC(=O)OCC(CC)CCCC)(|[S]CC(=O)OCC(CC)CCCC)|[S]CC(=O)OCC(CC)CCCC' for input: 'C[Sn](|[S]CC(=O)OCC(CC)CCCC)(|[S]CC(=O)OCC(CC)CCCC)|[S]CC(=O)OCC(CC)CCCC'
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] SMILES Parse Error: syntax error while parsing: [Cl]|[Sn](CCCC)(CCCC)CCCC
# [14:50:07] SMILES Parse Error: Failed parsing SMILES '[Cl]|[Sn](CCCC)(CCCC)CCCC' for input: '[Cl]|[Sn](CCCC)(CCCC)CCCC'
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] SMILES Parse Error: syntax error while parsing: [Cl]|[Pt--](|[Cl])(|[Cl])|[Cl].[K+].[K+]
# [14:50:07] SMILES Parse Error: Failed parsing SMILES '[Cl]|[Pt--](|[Cl])(|[Cl])|[Cl].[K+].[K+]' for input: '[Cl]|[Pt--](|[Cl])(|[Cl])|[Cl].[K+].[K+]'
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] WARNING: not removing hydrogen atom without neighbors
# [14:50:07] SMILES Parse Error: syntax error while parsing: [Zn++](|S=C([S-])N(CC)c1ccccc1)|S=C([S-])N(CC)c2ccccc2
# [14:50:07] SMILES Parse Error: Failed parsing SMILES '[Zn++](|S=C([S-])N(CC)c1ccccc1)|S=C([S-])N(CC)c2ccccc2' for input: '[Zn++](|S=C([S-])N(CC)c1ccccc1)|S=C([S-])N(CC)c2ccccc2'
# [14:50:08] SMILES Parse Error: syntax error while parsing: O|[Pd]|O
# [14:50:08] SMILES Parse Error: Failed parsing SMILES 'O|[Pd]|O' for input: 'O|[Pd]|O'
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] SMILES Parse Error: syntax error while parsing: CCCCCCCC[Sn]|1(|[O]C(=O)CC[S]|1)CCCCCCCC
# [14:50:08] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCC[Sn]|1(|[O]C(=O)CC[S]|1)CCCCCCCC' for input: 'CCCCCCCC[Sn]|1(|[O]C(=O)CC[S]|1)CCCCCCCC'
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] SMILES Parse Error: syntax error while parsing: CCCCCCCC[Sn](|[O]C(=O)C(CC)CCCC)(|[O]C(=O)C(CC)CCCC)CCCCCCCC
# [14:50:08] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCC[Sn](|[O]C(=O)C(CC)CCCC)(|[O]C(=O)C(CC)CCCC)CCCCCCCC' for input: 'CCCCCCCC[Sn](|[O]C(=O)C(CC)CCCC)(|[O]C(=O)C(CC)CCCC)CCCCCCCC'
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] Explicit valence for atom # 0 O, 3, is greater than permitted
# [14:50:08] SMILES Parse Error: syntax error while parsing: [NH4+].[NH4+].[Cl]|[Pd--](|[Cl])(|[Cl])(|[Cl])(|[Cl])|[Cl]
# [14:50:08] SMILES Parse Error: Failed parsing SMILES '[NH4+].[NH4+].[Cl]|[Pd--](|[Cl])(|[Cl])(|[Cl])(|[Cl])|[Cl]' for input: '[NH4+].[NH4+].[Cl]|[Pd--](|[Cl])(|[Cl])(|[Cl])(|[Cl])|[Cl]'
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] SMILES Parse Error: syntax error while parsing: [Cl]|[Pd--](|[Cl])(|[Cl])(|[Cl])(|[Cl])|[Cl].[K+].[K+]
# [14:50:08] SMILES Parse Error: Failed parsing SMILES '[Cl]|[Pd--](|[Cl])(|[Cl])(|[Cl])(|[Cl])|[Cl].[K+].[K+]' for input: '[Cl]|[Pd--](|[Cl])(|[Cl])(|[Cl])(|[Cl])|[Cl].[K+].[K+]'
# [14:50:08] SMILES Parse Error: syntax error while parsing: CCCCCCCC[Sn](|[O]C(=O)\C=C\C(=O)OCC)(|[O]C(=O)\C=C\C(=O)OCC)CCCCCCCC
# [14:50:08] SMILES Parse Error: Failed parsing SMILES 'CCCCCCCC[Sn](|[O]C(=O)\C=C\C(=O)OCC)(|[O]C(=O)\C=C\C(=O)OCC)CCCCCCCC' for input: 'CCCCCCCC[Sn](|[O]C(=O)\C=C\C(=O)OCC)(|[O]C(=O)\C=C\C(=O)OCC)CCCCCCCC'
# [14:50:08] SMILES Parse Error: syntax error while parsing: [Cl]|[Pt--](|[Cl])(|[Cl])(|[Cl])(|[Cl])|[Cl].[H+].[H+]
# [14:50:08] SMILES Parse Error: Failed parsing SMILES '[Cl]|[Pt--](|[Cl])(|[Cl])(|[Cl])(|[Cl])|[Cl].[H+].[H+]' for input: '[Cl]|[Pt--](|[Cl])(|[Cl])(|[Cl])(|[Cl])|[Cl].[H+].[H+]'
# [14:50:08] SMILES Parse Error: syntax error while parsing: [Cl]|[Pt--](|[Cl])(|[Cl])(|[Cl])(|[Cl])|[Cl].[K+].[K+]
# [14:50:08] SMILES Parse Error: Failed parsing SMILES '[Cl]|[Pt--](|[Cl])(|[Cl])(|[Cl])(|[Cl])|[Cl].[K+].[K+]' for input: '[Cl]|[Pt--](|[Cl])(|[Cl])(|[Cl])(|[Cl])|[Cl].[K+].[K+]'
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] SMILES Parse Error: syntax error while parsing: [Cl]|[Sn](|[Cl])(|[Cl])|[Cl]
# [14:50:08] SMILES Parse Error: Failed parsing SMILES '[Cl]|[Sn](|[Cl])(|[Cl])|[Cl]' for input: '[Cl]|[Sn](|[Cl])(|[Cl])|[Cl]'
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# Process completed. Check 'log.txt' for details.
#           CAS No                         Canonical SMILES  LLNA_EC3  binary  \
# 0     18479-49-7                       CC(C)CCCC(C)(O)C=C       NaN       0
# 1        93-84-5            [O-][N+](=O)c1ccc2NC(=O)Nc2c1       NaN       0
# 2     38725-13-2     CC(C)CCCCCCN(CCCCCCC(C)C)CCCCCCC(C)C       NaN       1
# 3     49701-24-8           CN[S](=O)(=O)c1cc(OC)c(N)cc1OC       NaN       0
# 4      3874-54-2                    Fc1ccc(cc1)C(=O)CCCCl       NaN       1
# ...          ...                                      ...       ...     ...
# 3297    103-50-4                    C(OCc1ccccc1)c2ccccc2      6.30       0
# 3298   1335-66-6  CC1CC(=CC(C)C1C=O)C.CC2C=C(C)CC(C=O)C2C      7.35       0
# 3299   5462-06-6                     COc1ccc(CC(C)C=O)cc1     23.63       0
# 3302  54464-57-2        CC1CC2=C(CC1(C)C(C)=O)C(C)(C)CCC2     25.14       0
# 3306   6658-48-6                 CC(C)Cc1ccc(CC(C)C=O)cc1      7.60       0
#
#      Source
# 0      ECHA
# 1      ECHA
# 2      ECHA
# 3      ECHA
# 4      ECHA
# ...     ...
# 3297  CosEU
# 3298  CosEU
# 3299  CosEU
# 3302  CosEU
# 3306  CosEU
#
# [1928 rows x 5 columns]
#           CAS No                                   Canonical SMILES  LLNA_EC3  \
# 58    20427-58-1                                           O|[Zn]|O       NaN
# 59    20427-58-1                                           O|[Zn]|O       NaN
# 75     1307-86-4                                       O|[Co](|O)|O       NaN
# 262   14025-15-1  [Na+].[Na+].[Cu]|1|OC(=O)CN(CCN(CC(O|1)=O)CC([...       NaN
# 285   68413-60-5  N.N.O|[Fe]|1|OC(=O)CN(CCN(CC(O)=O)CC(O)=O)CC(O...       NaN
# ...          ...                                                ...       ...
# 3311    111-80-8                                   CCCCCCC#CC(=O)OC       2.5
# 3312     93-51-6                                     COc1cc(C)ccc1O       5.4
# 3313     93-51-6                                     COc1cc(C)ccc1O       5.8
# 3317  17369-59-4                            CC/C=C/1OC(=O)c2ccccc12       3.7
# 3318  17369-59-4                            CC/C=C/1OC(=O)c2ccccc12       3.1
#
#       binary Source                Reason         canonical_smiles
# 58         0   ECHA        Invalid SMILES                      NaN
# 59         0   ECHA        Invalid SMILES                      NaN
# 75         0   ECHA        Invalid SMILES                      NaN
# 262        0   ECHA        Invalid SMILES                      NaN
# 285        0   ECHA        Invalid SMILES                      NaN
# ...      ...    ...                   ...                      ...
# 3311       1  CosEU  Concordant Duplicate         CCCCCCC#CC(=O)OC
# 3312       0  CosEU  Concordant Duplicate           COc1cc(C)ccc1O
# 3313       0  CosEU  Concordant Duplicate           COc1cc(C)ccc1O
# 3317       0  CosEU  Concordant Duplicate  CC/C=C1\OC(=O)c2ccccc21
# 3318       0  CosEU  Concordant Duplicate  CC/C=C1\OC(=O)c2ccccc21
#
# [1768 rows x 7 columns]
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# [14:50:08] WARNING: not removing hydrogen atom without neighbors
# C:\Users\franc\AppData\Local\Temp\ipykernel_26892\1027166548.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['canonical_smiles'] = df[smiles_col].apply(canonize_smiles)
# C:\Users\franc\AppData\Local\Temp\ipykernel_26892\1027166548.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   discordant_duplicates['Reason'] = 'Discordant Duplicate'
# C:\Users\franc\AppData\Local\Temp\ipykernel_26892\1027166548.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   concordant_duplicates['Reason'] = 'Concordant Duplicate'
